# %%
import os
import sys
print(os.getcwd())
sys.path.append("../WanPy")

from pythtb import *
import numpy as np
from pythTB_wan import Bloch, K_mesh, Wannier, Lattice, Model
# Out:
# /Users/treycole/Codes/WanPy/dev notebooks

# %%
def Haldane(delta, t, t2):
    lat=[[1, 0],[0.5, np.sqrt(3)/2]]
    orb=[[1/3, 1/3],[2/3, 2/3]]

    model = tb_model(2, 2, lat, orb)

    model.set_onsite([-delta, delta], mode='reset')

    for lvec in ([0, 0], [-1, 0], [0, -1]):
        model.set_hop(t, 0, 1, lvec, mode='reset')
        model.set_hop(t, 0, 1, lvec, mode='reset')

    for lvec in ([1, 0], [-1, 1], [0, -1]):
        model.set_hop(t2*1j, 0, 0, lvec, mode='reset')
        model.set_hop(t2*-1j, 1, 1, lvec, mode='reset')

    return model

def Haldane2(delta, t, t2):
    lat=[[1, 0],[0.5, np.sqrt(3)/2]]
    orb=[[1/3, 1/3],[2/3, 2/3]]

    model = Model(2, 2, lat, orb)

    model.set_onsite([-delta, delta], mode='reset')

    for lvec in ([0, 0], [-1, 0], [0, -1]):
        model.set_hop(t, 0, 1, lvec, mode='reset')
        model.set_hop(t, 0, 1, lvec, mode='reset')

    for lvec in ([1, 0], [-1, 1], [0, -1]):
        model.set_hop(t2*1j, 0, 0, lvec, mode='reset')
        model.set_hop(t2*-1j, 1, 1, lvec, mode='reset')

    return model

# %%
hal = Haldane(1, 1, 1)
hal2 = Haldane2(1, 1, 1)

# %%
k_mesh = K_mesh(hal, 10, 10)
full_mesh = k_mesh.gen_k_mesh(endpoint=True)
eig1 = hal.solve_all(full_mesh)
eig2 = hal2.solve_ham(full_mesh)
np.allclose(eig1, eig2.T)
# Out:
# True

# %%
ham1 = hal2._gen_ham(full_mesh[0])
ham_2 = hal2.get_ham(full_mesh[0])
print(np.allclose(ham1, ham_2))
# Out:
# True

# %%
# %load_ext line_profiler
# %lprun -f hal.solve_all hal.solve_all(full_mesh)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.009225 s
# File: /Users/treycole/miniforge3/envs/rutgers/lib/python3.10/site-packages/pythtb.py
# Function: solve_all at line 955
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    955                                               def solve_all(self,k_list=None,eig_vectors=False):
#    956                                                   r"""
#    957                                                   Solves for eigenvalues and (optionally) eigenvectors of the
#    958                                                   tight-binding model on a given one-dimensional list of k-vectors.
#    959
#    960                                                   .. note::
#    961
#    962                                                      Eigenvectors (wavefunctions) returned by this
#    963                                                      function and used throughout the code are exclusively given
#    964                                                      in convention 1 as described in section 3.1 of
#    965                                                      :download:`notes on tight-binding formalism
#    966                                                      <misc/pythtb-formalism.pdf>`.  In other words, they
#    967                                                      are in correspondence with cell-periodic functions
#    968                                                      :math:`u_{n {\bf k}} ({\bf r})` not
#    969                                                      :math:`\Psi_{n {\bf k}} ({\bf r})`.
#    970
#    971                                                   .. note::
#    972
#    973                                                      In some cases class :class:`pythtb.wf_array` provides a more
#    974                                                      elegant way to deal with eigensolutions on a regular mesh of
#    975                                                      k-vectors.
#    976
#    977                                                   :param k_list: One-dimensional array of k-vectors. Each k-vector
#    978                                                     is given in reduced coordinates of the reciprocal space unit
#    979                                                     cell. For example, for real space unit cell vectors [1.0,0.0]
#    980                                                     and [0.0,2.0] and associated reciprocal space unit vectors
#    981                                                     [2.0*pi,0.0] and [0.0,pi], k-vector with reduced coordinates
#    982                                                     [0.25,0.25] corresponds to k-vector [0.5*pi,0.25*pi].
#    983                                                     Dimensionality of each vector must equal to the number of
#    984                                                     periodic directions (i.e. dimensionality of reciprocal space,
#    985                                                     *dim_k*).
#    986                                                     This parameter shouldn't be specified for system with
#    987                                                     zero-dimensional k-space (*dim_k* =0).
#    988
#    989                                                   :param eig_vectors: Optional boolean parameter, specifying whether
#    990                                                     eigenvectors should be returned. If *eig_vectors* is True, then
#    991                                                     both eigenvalues and eigenvectors are returned, otherwise only
#    992                                                     eigenvalues are returned.
#    993
#    994                                                   :returns:
#    995                                                     * **eval** -- Two dimensional array of eigenvalues for
#    996                                                       all bands for all kpoints. Format is eval[band,kpoint] where
#    997                                                       first index (band) corresponds to the electron band in
#    998                                                       question and second index (kpoint) corresponds to the k-point
#    999                                                       as listed in the input parameter *k_list*. Eigenvalues are
#   1000                                                       sorted from smallest to largest at each k-point seperately.
#   1001
#   1002                                                       In the case when reciprocal space is zero-dimensional (as in a
#   1003                                                       molecule) kpoint index is dropped and *eval* is of the format
#   1004                                                       eval[band].
#   1005
#   1006                                                     * **evec** -- Three dimensional array of eigenvectors for
#   1007                                                       all bands and all kpoints. If *nspin* equals 1 the format
#   1008                                                       of *evec* is evec[band,kpoint,orbital] where "band" is the
#   1009                                                       electron band in question, "kpoint" is index of k-vector
#   1010                                                       as given in input parameter *k_list*. Finally, "orbital"
#   1011                                                       refers to the tight-binding orbital basis function.
#   1012                                                       Ordering of bands is the same as in *eval*.
#   1013
#   1014                                                       Eigenvectors evec[n,k,j] correspond to :math:`C^{n {\bf
#   1015                                                       k}}_{j}` from section 3.1 equation 3.5 and 3.7 of the
#   1016                                                       :download:`notes on tight-binding formalism
#   1017                                                       <misc/pythtb-formalism.pdf>`.
#   1018
#   1019                                                       In the case when reciprocal space is zero-dimensional (as in a
#   1020                                                       molecule) kpoint index is dropped and *evec* is of the format
#   1021                                                       evec[band,orbital].
#   1022
#   1023                                                       In the spinfull calculation (*nspin* equals 2) evec has
#   1024                                                       additional component evec[...,spin] corresponding to the
#   1025                                                       spin component of the wavefunction.
#   1026
#   1027                                                   Example usage::
#   1028
#   1029                                                     # Returns eigenvalues for three k-vectors
#   1030                                                     eval = tb.solve_all([[0.0, 0.0], [0.0, 0.2], [0.0, 0.5]])
#   1031                                                     # Returns eigenvalues and eigenvectors for two k-vectors
#   1032                                                     (eval, evec) = tb.solve_all([[0.0, 0.0], [0.0, 0.2]], eig_vectors=True)
#   1033
#   1034                                                   """
#   1035                                                   # if not 0-dim case
#   1036         1          0.0      0.0      0.0          if not (k_list is None):
#   1037         1          0.0      0.0      0.0              nkp=len(k_list) # number of k points
#   1038                                                       # first initialize matrices for all return data
#   1039                                                       #    indices are [band,kpoint]
#   1040         1       6000.0   6000.0      0.1              ret_eval=np.zeros((self._nsta,nkp),dtype=float)
#   1041                                                       #    indices are [band,kpoint,orbital,spin]
#   1042         1       1000.0   1000.0      0.0              if self._nspin==1:
#   1043         1       1000.0   1000.0      0.0                  ret_evec=np.zeros((self._nsta,nkp,self._norb),dtype=complex)
#   1044                                                       elif self._nspin==2:
#   1045                                                           ret_evec=np.zeros((self._nsta,nkp,self._norb,2),dtype=complex)
#   1046                                                       # go over all kpoints
#   1047       101      36000.0    356.4      0.4              for i,k in enumerate(k_list):
#   1048                                                           # generate Hamiltonian at that point
#   1049       100    4581000.0  45810.0     49.7                  ham=self._gen_ham(k)
#   1050                                                           # solve Hamiltonian
#   1051       100      24000.0    240.0      0.3                  if eig_vectors==False:
#   1052       100    4494000.0  44940.0     48.7                      eval=self._sol_ham(ham,eig_vectors=eig_vectors)
#   1053       100      81000.0    810.0      0.9                      ret_eval[:,i]=eval[:]
#   1054                                                           else:
#   1055                                                               (eval,evec)=self._sol_ham(ham,eig_vectors=eig_vectors)
#   1056                                                               ret_eval[:,i]=eval[:]
#   1057                                                               if self._nspin==1:
#   1058                                                                   ret_evec[:,i,:]=evec[:,:]
#   1059                                                               elif self._nspin==2:
#   1060                                                                   ret_evec[:,i,:,:]=evec[:,:,:]
#   1061                                                       # return stuff
#   1062         1          0.0      0.0      0.0              if eig_vectors==False:
#   1063                                                           # indices of eval are [band,kpoint]
#   1064         1       1000.0   1000.0      0.0                  return ret_eval
#   1065                                                       else:
#   1066                                                           # indices of eval are [band,kpoint] for evec are [band,kpoint,orbital,(spin)]
#   1067                                                           return (ret_eval,ret_evec)
#   1068                                                   else: # 0 dim case
#   1069                                                       # generate Hamiltonian
#   1070                                                       ham=self._gen_ham()
#   1071                                                       # solve
#   1072                                                       if eig_vectors==False:
#   1073                                                           eval=self._sol_ham(ham,eig_vectors=eig_vectors)
#   1074                                                           # indices of eval are [band]
#   1075                                                           return eval
#   1076                                                       else:
#   1077                                                           (eval,evec)=self._sol_ham(ham,eig_vectors=eig_vectors)
#   1078                                                           # indices of eval are [band] and of evec are [band,orbital,spin]
#   1079                                                           return (eval,evec)

# %%
# result1 = %timeit -o hal.solve_all(full_mesh)
# result1

# %%
# %timeit hal2.solve_ham(full_mesh)

# %%
import time

nk_arr = np.arange(1, 100, 1)
results1 = np.zeros(nk_arr.shape[0])
results2 = np.zeros(nk_arr.shape[0])

for idx, nk in enumerate(nk_arr):
    # print(idx)
    k_mesh = K_mesh(hal, nk, nk)
    full_mesh = k_mesh.gen_k_mesh(endpoint=True)

    start = time.time()
    result1 = hal.solve_all(full_mesh)
    stop = time.time()
    results1[idx] = start - stop

    start = time.time()
    result2 =  hal2.solve_ham(full_mesh)
    stop = time.time()
    results2[idx] = start - stop

# %%
import matplotlib.pyplot as plt

plt.scatter(nk_arr, -results1, label="PythTB.solve_all()", c='orange')
plt.scatter(nk_arr, -results2, label="Model.solve_ham()", c='b')
plt.legend()
plt.xlabel("Number of k-points")
plt.ylabel("time (s)")

plt.savefig("images/profiling_solve_ham.png")

# %%
import time

nk_arr = np.arange(1, 100, 1)
results1 = np.zeros(nk_arr.shape[0])
results2 = np.zeros(nk_arr.shape[0])

for idx, nk in enumerate(nk_arr):
    # print(idx)
    k_mesh = K_mesh(hal, nk, nk)
    full_mesh = k_mesh.gen_k_mesh(endpoint=True)

    start = time.time()
    for k in full_mesh:
        result1 = hal._gen_ham(k)
    stop = time.time()
    results1[idx] = start - stop

    start = time.time()
    result2 =  hal2.get_ham(full_mesh)
    stop = time.time()
    results2[idx] = start - stop

# %%
import matplotlib.pyplot as plt

plt.scatter(nk_arr, -results1, label="PythTB._gen_ham()", c='orange')
plt.scatter(nk_arr, -results2, label="Model.get_ham()", c='b')
plt.legend()
plt.xlabel("Number of k-points")
plt.ylabel("time (s)")

plt.savefig("images/profiling_gen_ham.png")

# %%
import numpy as np

# %%
max_R = 5
dim_r = 4

sc_cands=[]
if dim_r==1:
    for i in range(-max_R,max_R+1):
        sc_cands.append(np.array([i]))
elif dim_r==2:
    for i in range(-max_R,max_R+1):
        for j in range(-max_R,max_R+1):
            sc_cands.append(np.array([i,j]))
elif dim_r==3:
    for i in range(-max_R,max_R+1):
        for j in range(-max_R,max_R+1):
            for k in range(-max_R,max_R+1):
                sc_cands.append(np.array([i,j,k]))
elif dim_r==4:
    for i in range(-max_R,max_R+1):
        for j in range(-max_R,max_R+1):
            for k in range(-max_R,max_R+1):
                for l in range(-max_R,max_R+1):
                    sc_cands.append(np.array([i,j,k,l]))

sc_cands
# Out:
# [array([-5, -5, -5, -5]),
#  array([-5, -5, -5, -4]),
#  array([-5, -5, -5, -3]),
#  array([-5, -5, -5, -2]),
#  array([-5, -5, -5, -1]),
#  array([-5, -5, -5,  0]),
#  array([-5, -5, -5,  1]),
#  array([-5, -5, -5,  2]),
#  array([-5, -5, -5,  3]),
#  array([-5, -5, -5,  4]),
#  array([-5, -5, -5,  5]),
#  array([-5, -5, -4, -5]),
#  array([-5, -5, -4, -4]),
#  array([-5, -5, -4, -3]),
#  array([-5, -5, -4, -2]),
#  array([-5, -5, -4, -1]),
#  array([-5, -5, -4,  0]),
#  array([-5, -5, -4,  1]),
#  array([-5, -5, -4,  2]),
#  array([-5, -5, -4,  3]),
#  array([-5, -5, -4,  4]),
#  array([-5, -5, -4,  5]),
#  array([-5, -5, -3, -5]),
#  array([-5, -5, -3, -4]),
#  array([-5, -5, -3, -3]),
#  array([-5, -5, -3, -2]),
#  array([-5, -5, -3, -1]),
#  array([-5, -5, -3,  0]),
#  array([-5, -5, -3,  1]),
#  array([-5, -5, -3,  2]),
#  array([-5, -5, -3,  3]),
#  array([-5, -5, -3,  4]),
#  array([-5, -5, -3,  5]),
#  array([-5, -5, -2, -5]),
#  array([-5, -5, -2, -4]),
#  array([-5, -5, -2, -3]),
#  array([-5, -5, -2, -2]),
#  array([-5, -5, -2, -1]),
#  array([-5, -5, -2,  0]),
#  array([-5, -5, -2,  1]),
#  array([-5, -5, -2,  2]),
#  array([-5, -5, -2,  3]),
#  array([-5, -5, -2,  4]),
#  array([-5, -5, -2,  5]),
#  array([-5, -5, -1, -5]),
#  array([-5, -5, -1, -4]),
#  array([-5, -5, -1, -3]),
#  array([-5, -5, -1, -2]),
#  array([-5, -5, -1, -1]),
#  array([-5, -5, -1,  0]),
#  array([-5, -5, -1,  1]),
#  array([-5, -5, -1,  2]),
#  array([-5, -5, -1,  3]),
#  array([-5, -5, -1,  4]),
#  array([-5, -5, -1,  5]),
#  array([-5, -5,  0, -5]),
#  array([-5, -5,  0, -4]),
#  array([-5, -5,  0, -3]),
#  array([-5, -5,  0, -2]),
#  array([-5, -5,  0, -1]),
#  array([-5, -5,  0,  0]),
#  array([-5, -5,  0,  1]),
#  array([-5, -5,  0,  2]),
#  array([-5, -5,  0,  3]),
#  array([-5, -5,  0,  4]),
#  array([-5, -5,  0,  5]),
#  array([-5, -5,  1, -5]),
#  array([-5, -5,  1, -4]),
#  array([-5, -5,  1, -3]),
#  array([-5, -5,  1, -2]),
#  array([-5, -5,  1, -1]),
#  array([-5, -5,  1,  0]),
#  array([-5, -5,  1,  1]),
#  array([-5, -5,  1,  2]),
#  array([-5, -5,  1,  3]),
#  array([-5, -5,  1,  4]),
#  array([-5, -5,  1,  5]),
#  array([-5, -5,  2, -5]),
#  array([-5, -5,  2, -4]),
#  array([-5, -5,  2, -3]),
#  array([-5, -5,  2, -2]),
#  array([-5, -5,  2, -1]),
#  array([-5, -5,  2,  0]),
#  array([-5, -5,  2,  1]),
#  array([-5, -5,  2,  2]),
#  array([-5, -5,  2,  3]),
#  array([-5, -5,  2,  4]),
#  array([-5, -5,  2,  5]),
#  array([-5, -5,  3, -5]),
#  array([-5, -5,  3, -4]),
#  array([-5, -5,  3, -3]),
#  array([-5, -5,  3, -2]),
#  array([-5, -5,  3, -1]),
#  array([-5, -5,  3,  0]),
#  array([-5, -5,  3,  1]),
#  array([-5, -5,  3,  2]),
#  array([-5, -5,  3,  3]),
#  array([-5, -5,  3,  4]),
#  array([-5, -5,  3,  5]),
#  array([-5, -5,  4, -5]),
#  array([-5, -5,  4, -4]),
#  array([-5, -5,  4, -3]),
#  array([-5, -5,  4, -2]),
#  array([-5, -5,  4, -1]),
#  array([-5, -5,  4,  0]),
#  array([-5, -5,  4,  1]),
#  array([-5, -5,  4,  2]),
#  array([-5, -5,  4,  3]),
#  array([-5, -5,  4,  4]),
#  array([-5, -5,  4,  5]),
#  array([-5, -5,  5, -5]),
#  array([-5, -5,  5, -4]),
#  array([-5, -5,  5, -3]),
#  array([-5, -5,  5, -2]),
#  array([-5, -5,  5, -1]),
#  array([-5, -5,  5,  0]),
#  array([-5, -5,  5,  1]),
#  array([-5, -5,  5,  2]),
#  array([-5, -5,  5,  3]),
#  array([-5, -5,  5,  4]),
#  array([-5, -5,  5,  5]),
#  array([-5, -4, -5, -5]),
#  array([-5, -4, -5, -4]),
#  array([-5, -4, -5, -3]),
#  array([-5, -4, -5, -2]),
#  array([-5, -4, -5, -1]),
#  array([-5, -4, -5,  0]),
#  array([-5, -4, -5,  1]),
#  array([-5, -4, -5,  2]),
#  array([-5, -4, -5,  3]),
#  array([-5, -4, -5,  4]),
#  array([-5, -4, -5,  5]),
#  array([-5, -4, -4, -5]),
#  array([-5, -4, -4, -4]),
#  array([-5, -4, -4, -3]),
#  array([-5, -4, -4, -2]),
#  array([-5, -4, -4, -1]),
#  array([-5, -4, -4,  0]),
#  array([-5, -4, -4,  1]),
#  array([-5, -4, -4,  2]),
#  array([-5, -4, -4,  3]),
#  array([-5, -4, -4,  4]),
#  array([-5, -4, -4,  5]),
#  array([-5, -4, -3, -5]),
#  array([-5, -4, -3, -4]),
#  array([-5, -4, -3, -3]),
#  array([-5, -4, -3, -2]),
#  array([-5, -4, -3, -1]),
#  array([-5, -4, -3,  0]),
#  array([-5, -4, -3,  1]),
#  array([-5, -4, -3,  2]),
#  array([-5, -4, -3,  3]),
#  array([-5, -4, -3,  4]),
#  array([-5, -4, -3,  5]),
#  array([-5, -4, -2, -5]),
#  array([-5, -4, -2, -4]),
#  array([-5, -4, -2, -3]),
#  array([-5, -4, -2, -2]),
#  array([-5, -4, -2, -1]),
#  array([-5, -4, -2,  0]),
#  array([-5, -4, -2,  1]),
#  array([-5, -4, -2,  2]),
#  array([-5, -4, -2,  3]),
#  array([-5, -4, -2,  4]),
#  array([-5, -4, -2,  5]),
#  array([-5, -4, -1, -5]),
#  array([-5, -4, -1, -4]),
#  array([-5, -4, -1, -3]),
#  array([-5, -4, -1, -2]),
#  array([-5, -4, -1, -1]),
#  array([-5, -4, -1,  0]),
#  array([-5, -4, -1,  1]),
#  array([-5, -4, -1,  2]),
#  array([-5, -4, -1,  3]),
#  array([-5, -4, -1,  4]),
#  array([-5, -4, -1,  5]),
#  array([-5, -4,  0, -5]),
#  array([-5, -4,  0, -4]),
#  array([-5, -4,  0, -3]),
#  array([-5, -4,  0, -2]),
#  array([-5, -4,  0, -1]),
#  array([-5, -4,  0,  0]),
#  array([-5, -4,  0,  1]),
#  array([-5, -4,  0,  2]),
#  array([-5, -4,  0,  3]),
#  array([-5, -4,  0,  4]),
#  array([-5, -4,  0,  5]),
#  array([-5, -4,  1, -5]),
#  array([-5, -4,  1, -4]),
#  array([-5, -4,  1, -3]),
#  array([-5, -4,  1, -2]),
#  array([-5, -4,  1, -1]),
#  array([-5, -4,  1,  0]),
#  array([-5, -4,  1,  1]),
#  array([-5, -4,  1,  2]),
#  array([-5, -4,  1,  3]),
#  array([-5, -4,  1,  4]),
#  array([-5, -4,  1,  5]),
#  array([-5, -4,  2, -5]),
#  array([-5, -4,  2, -4]),
#  array([-5, -4,  2, -3]),
#  array([-5, -4,  2, -2]),
#  array([-5, -4,  2, -1]),
#  array([-5, -4,  2,  0]),
#  array([-5, -4,  2,  1]),
#  array([-5, -4,  2,  2]),
#  array([-5, -4,  2,  3]),
#  array([-5, -4,  2,  4]),
#  array([-5, -4,  2,  5]),
#  array([-5, -4,  3, -5]),
#  array([-5, -4,  3, -4]),
#  array([-5, -4,  3, -3]),
#  array([-5, -4,  3, -2]),
#  array([-5, -4,  3, -1]),
#  array([-5, -4,  3,  0]),
#  array([-5, -4,  3,  1]),
#  array([-5, -4,  3,  2]),
#  array([-5, -4,  3,  3]),
#  array([-5, -4,  3,  4]),
#  array([-5, -4,  3,  5]),
#  array([-5, -4,  4, -5]),
#  array([-5, -4,  4, -4]),
#  array([-5, -4,  4, -3]),
#  array([-5, -4,  4, -2]),
#  array([-5, -4,  4, -1]),
#  array([-5, -4,  4,  0]),
#  array([-5, -4,  4,  1]),
#  array([-5, -4,  4,  2]),
#  array([-5, -4,  4,  3]),
#  array([-5, -4,  4,  4]),
#  array([-5, -4,  4,  5]),
#  array([-5, -4,  5, -5]),
#  array([-5, -4,  5, -4]),
#  array([-5, -4,  5, -3]),
#  array([-5, -4,  5, -2]),
#  array([-5, -4,  5, -1]),
#  array([-5, -4,  5,  0]),
#  array([-5, -4,  5,  1]),
#  array([-5, -4,  5,  2]),
#  array([-5, -4,  5,  3]),
#  array([-5, -4,  5,  4]),
#  array([-5, -4,  5,  5]),
#  array([-5, -3, -5, -5]),
#  array([-5, -3, -5, -4]),
#  array([-5, -3, -5, -3]),
#  array([-5, -3, -5, -2]),
#  array([-5, -3, -5, -1]),
#  array([-5, -3, -5,  0]),
#  array([-5, -3, -5,  1]),
#  array([-5, -3, -5,  2]),
#  array([-5, -3, -5,  3]),
#  array([-5, -3, -5,  4]),
#  array([-5, -3, -5,  5]),
#  array([-5, -3, -4, -5]),
#  array([-5, -3, -4, -4]),
#  array([-5, -3, -4, -3]),
#  array([-5, -3, -4, -2]),
#  array([-5, -3, -4, -1]),
#  array([-5, -3, -4,  0]),
#  array([-5, -3, -4,  1]),
#  array([-5, -3, -4,  2]),
#  array([-5, -3, -4,  3]),
#  array([-5, -3, -4,  4]),
#  array([-5, -3, -4,  5]),
#  array([-5, -3, -3, -5]),
#  array([-5, -3, -3, -4]),
#  array([-5, -3, -3, -3]),
#  array([-5, -3, -3, -2]),
#  array([-5, -3, -3, -1]),
#  array([-5, -3, -3,  0]),
#  array([-5, -3, -3,  1]),
#  array([-5, -3, -3,  2]),
#  array([-5, -3, -3,  3]),
#  array([-5, -3, -3,  4]),
#  array([-5, -3, -3,  5]),
#  array([-5, -3, -2, -5]),
#  array([-5, -3, -2, -4]),
#  array([-5, -3, -2, -3]),
#  array([-5, -3, -2, -2]),
#  array([-5, -3, -2, -1]),
#  array([-5, -3, -2,  0]),
#  array([-5, -3, -2,  1]),
#  array([-5, -3, -2,  2]),
#  array([-5, -3, -2,  3]),
#  array([-5, -3, -2,  4]),
#  array([-5, -3, -2,  5]),
#  array([-5, -3, -1, -5]),
#  array([-5, -3, -1, -4]),
#  array([-5, -3, -1, -3]),
#  array([-5, -3, -1, -2]),
#  array([-5, -3, -1, -1]),
#  array([-5, -3, -1,  0]),
#  array([-5, -3, -1,  1]),
#  array([-5, -3, -1,  2]),
#  array([-5, -3, -1,  3]),
#  array([-5, -3, -1,  4]),
#  array([-5, -3, -1,  5]),
#  array([-5, -3,  0, -5]),
#  array([-5, -3,  0, -4]),
#  array([-5, -3,  0, -3]),
#  array([-5, -3,  0, -2]),
#  array([-5, -3,  0, -1]),
#  array([-5, -3,  0,  0]),
#  array([-5, -3,  0,  1]),
#  array([-5, -3,  0,  2]),
#  array([-5, -3,  0,  3]),
#  array([-5, -3,  0,  4]),
#  array([-5, -3,  0,  5]),
#  array([-5, -3,  1, -5]),
#  array([-5, -3,  1, -4]),
#  array([-5, -3,  1, -3]),
#  array([-5, -3,  1, -2]),
#  array([-5, -3,  1, -1]),
#  array([-5, -3,  1,  0]),
#  array([-5, -3,  1,  1]),
#  array([-5, -3,  1,  2]),
#  array([-5, -3,  1,  3]),
#  array([-5, -3,  1,  4]),
#  array([-5, -3,  1,  5]),
#  array([-5, -3,  2, -5]),
#  array([-5, -3,  2, -4]),
#  array([-5, -3,  2, -3]),
#  array([-5, -3,  2, -2]),
#  array([-5, -3,  2, -1]),
#  array([-5, -3,  2,  0]),
#  array([-5, -3,  2,  1]),
#  array([-5, -3,  2,  2]),
#  array([-5, -3,  2,  3]),
#  array([-5, -3,  2,  4]),
#  array([-5, -3,  2,  5]),
#  array([-5, -3,  3, -5]),
#  array([-5, -3,  3, -4]),
#  array([-5, -3,  3, -3]),
#  array([-5, -3,  3, -2]),
#  array([-5, -3,  3, -1]),
#  array([-5, -3,  3,  0]),
#  array([-5, -3,  3,  1]),
#  array([-5, -3,  3,  2]),
#  array([-5, -3,  3,  3]),
#  array([-5, -3,  3,  4]),
#  array([-5, -3,  3,  5]),
#  array([-5, -3,  4, -5]),
#  array([-5, -3,  4, -4]),
#  array([-5, -3,  4, -3]),
#  array([-5, -3,  4, -2]),
#  array([-5, -3,  4, -1]),
#  array([-5, -3,  4,  0]),
#  array([-5, -3,  4,  1]),
#  array([-5, -3,  4,  2]),
#  array([-5, -3,  4,  3]),
#  array([-5, -3,  4,  4]),
#  array([-5, -3,  4,  5]),
#  array([-5, -3,  5, -5]),
#  array([-5, -3,  5, -4]),
#  array([-5, -3,  5, -3]),
#  array([-5, -3,  5, -2]),
#  array([-5, -3,  5, -1]),
#  array([-5, -3,  5,  0]),
#  array([-5, -3,  5,  1]),
#  array([-5, -3,  5,  2]),
#  array([-5, -3,  5,  3]),
#  array([-5, -3,  5,  4]),
#  array([-5, -3,  5,  5]),
#  array([-5, -2, -5, -5]),
#  array([-5, -2, -5, -4]),
#  array([-5, -2, -5, -3]),
#  array([-5, -2, -5, -2]),
#  array([-5, -2, -5, -1]),
#  array([-5, -2, -5,  0]),
#  array([-5, -2, -5,  1]),
#  array([-5, -2, -5,  2]),
#  array([-5, -2, -5,  3]),
#  array([-5, -2, -5,  4]),
#  array([-5, -2, -5,  5]),
#  array([-5, -2, -4, -5]),
#  array([-5, -2, -4, -4]),
#  array([-5, -2, -4, -3]),
#  array([-5, -2, -4, -2]),
#  array([-5, -2, -4, -1]),
#  array([-5, -2, -4,  0]),
#  array([-5, -2, -4,  1]),
#  array([-5, -2, -4,  2]),
#  array([-5, -2, -4,  3]),
#  array([-5, -2, -4,  4]),
#  array([-5, -2, -4,  5]),
#  array([-5, -2, -3, -5]),
#  array([-5, -2, -3, -4]),
#  array([-5, -2, -3, -3]),
#  array([-5, -2, -3, -2]),
#  array([-5, -2, -3, -1]),
#  array([-5, -2, -3,  0]),
#  array([-5, -2, -3,  1]),
#  array([-5, -2, -3,  2]),
#  array([-5, -2, -3,  3]),
#  array([-5, -2, -3,  4]),
#  array([-5, -2, -3,  5]),
#  array([-5, -2, -2, -5]),
#  array([-5, -2, -2, -4]),
#  array([-5, -2, -2, -3]),
#  array([-5, -2, -2, -2]),
#  array([-5, -2, -2, -1]),
#  array([-5, -2, -2,  0]),
#  array([-5, -2, -2,  1]),
#  array([-5, -2, -2,  2]),
#  array([-5, -2, -2,  3]),
#  array([-5, -2, -2,  4]),
#  array([-5, -2, -2,  5]),
#  array([-5, -2, -1, -5]),
#  array([-5, -2, -1, -4]),
#  array([-5, -2, -1, -3]),
#  array([-5, -2, -1, -2]),
#  array([-5, -2, -1, -1]),
#  array([-5, -2, -1,  0]),
#  array([-5, -2, -1,  1]),
#  array([-5, -2, -1,  2]),
#  array([-5, -2, -1,  3]),
#  array([-5, -2, -1,  4]),
#  array([-5, -2, -1,  5]),
#  array([-5, -2,  0, -5]),
#  array([-5, -2,  0, -4]),
#  array([-5, -2,  0, -3]),
#  array([-5, -2,  0, -2]),
#  array([-5, -2,  0, -1]),
#  array([-5, -2,  0,  0]),
#  array([-5, -2,  0,  1]),
#  array([-5, -2,  0,  2]),
#  array([-5, -2,  0,  3]),
#  array([-5, -2,  0,  4]),
#  array([-5, -2,  0,  5]),
#  array([-5, -2,  1, -5]),
#  array([-5, -2,  1, -4]),
#  array([-5, -2,  1, -3]),
#  array([-5, -2,  1, -2]),
#  array([-5, -2,  1, -1]),
#  array([-5, -2,  1,  0]),
#  array([-5, -2,  1,  1]),
#  array([-5, -2,  1,  2]),
#  array([-5, -2,  1,  3]),
#  array([-5, -2,  1,  4]),
#  array([-5, -2,  1,  5]),
#  array([-5, -2,  2, -5]),
#  array([-5, -2,  2, -4]),
#  array([-5, -2,  2, -3]),
#  array([-5, -2,  2, -2]),
#  array([-5, -2,  2, -1]),
#  array([-5, -2,  2,  0]),
#  array([-5, -2,  2,  1]),
#  array([-5, -2,  2,  2]),
#  array([-5, -2,  2,  3]),
#  array([-5, -2,  2,  4]),
#  array([-5, -2,  2,  5]),
#  array([-5, -2,  3, -5]),
#  array([-5, -2,  3, -4]),
#  array([-5, -2,  3, -3]),
#  array([-5, -2,  3, -2]),
#  array([-5, -2,  3, -1]),
#  array([-5, -2,  3,  0]),
#  array([-5, -2,  3,  1]),
#  array([-5, -2,  3,  2]),
#  array([-5, -2,  3,  3]),
#  array([-5, -2,  3,  4]),
#  array([-5, -2,  3,  5]),
#  array([-5, -2,  4, -5]),
#  array([-5, -2,  4, -4]),
#  array([-5, -2,  4, -3]),
#  array([-5, -2,  4, -2]),
#  array([-5, -2,  4, -1]),
#  array([-5, -2,  4,  0]),
#  array([-5, -2,  4,  1]),
#  array([-5, -2,  4,  2]),
#  array([-5, -2,  4,  3]),
#  array([-5, -2,  4,  4]),
#  array([-5, -2,  4,  5]),
#  array([-5, -2,  5, -5]),
#  array([-5, -2,  5, -4]),
#  array([-5, -2,  5, -3]),
#  array([-5, -2,  5, -2]),
#  array([-5, -2,  5, -1]),
#  array([-5, -2,  5,  0]),
#  array([-5, -2,  5,  1]),
#  array([-5, -2,  5,  2]),
#  array([-5, -2,  5,  3]),
#  array([-5, -2,  5,  4]),
#  array([-5, -2,  5,  5]),
#  array([-5, -1, -5, -5]),
#  array([-5, -1, -5, -4]),
#  array([-5, -1, -5, -3]),
#  array([-5, -1, -5, -2]),
#  array([-5, -1, -5, -1]),
#  array([-5, -1, -5,  0]),
#  array([-5, -1, -5,  1]),
#  array([-5, -1, -5,  2]),
#  array([-5, -1, -5,  3]),
#  array([-5, -1, -5,  4]),
#  array([-5, -1, -5,  5]),
#  array([-5, -1, -4, -5]),
#  array([-5, -1, -4, -4]),
#  array([-5, -1, -4, -3]),
#  array([-5, -1, -4, -2]),
#  array([-5, -1, -4, -1]),
#  array([-5, -1, -4,  0]),
#  array([-5, -1, -4,  1]),
#  array([-5, -1, -4,  2]),
#  array([-5, -1, -4,  3]),
#  array([-5, -1, -4,  4]),
#  array([-5, -1, -4,  5]),
#  array([-5, -1, -3, -5]),
#  array([-5, -1, -3, -4]),
#  array([-5, -1, -3, -3]),
#  array([-5, -1, -3, -2]),
#  array([-5, -1, -3, -1]),
#  array([-5, -1, -3,  0]),
#  array([-5, -1, -3,  1]),
#  array([-5, -1, -3,  2]),
#  array([-5, -1, -3,  3]),
#  array([-5, -1, -3,  4]),
#  array([-5, -1, -3,  5]),
#  array([-5, -1, -2, -5]),
#  array([-5, -1, -2, -4]),
#  array([-5, -1, -2, -3]),
#  array([-5, -1, -2, -2]),
#  array([-5, -1, -2, -1]),
#  array([-5, -1, -2,  0]),
#  array([-5, -1, -2,  1]),
#  array([-5, -1, -2,  2]),
#  array([-5, -1, -2,  3]),
#  array([-5, -1, -2,  4]),
#  array([-5, -1, -2,  5]),
#  array([-5, -1, -1, -5]),
#  array([-5, -1, -1, -4]),
#  array([-5, -1, -1, -3]),
#  array([-5, -1, -1, -2]),
#  array([-5, -1, -1, -1]),
#  array([-5, -1, -1,  0]),
#  array([-5, -1, -1,  1]),
#  array([-5, -1, -1,  2]),
#  array([-5, -1, -1,  3]),
#  array([-5, -1, -1,  4]),
#  array([-5, -1, -1,  5]),
#  array([-5, -1,  0, -5]),
#  array([-5, -1,  0, -4]),
#  array([-5, -1,  0, -3]),
#  array([-5, -1,  0, -2]),
#  array([-5, -1,  0, -1]),
#  array([-5, -1,  0,  0]),
#  array([-5, -1,  0,  1]),
#  array([-5, -1,  0,  2]),
#  array([-5, -1,  0,  3]),
#  array([-5, -1,  0,  4]),
#  array([-5, -1,  0,  5]),
#  array([-5, -1,  1, -5]),
#  array([-5, -1,  1, -4]),
#  array([-5, -1,  1, -3]),
#  array([-5, -1,  1, -2]),
#  array([-5, -1,  1, -1]),
#  array([-5, -1,  1,  0]),
#  array([-5, -1,  1,  1]),
#  array([-5, -1,  1,  2]),
#  array([-5, -1,  1,  3]),
#  array([-5, -1,  1,  4]),
#  array([-5, -1,  1,  5]),
#  array([-5, -1,  2, -5]),
#  array([-5, -1,  2, -4]),
#  array([-5, -1,  2, -3]),
#  array([-5, -1,  2, -2]),
#  array([-5, -1,  2, -1]),
#  array([-5, -1,  2,  0]),
#  array([-5, -1,  2,  1]),
#  array([-5, -1,  2,  2]),
#  array([-5, -1,  2,  3]),
#  array([-5, -1,  2,  4]),
#  array([-5, -1,  2,  5]),
#  array([-5, -1,  3, -5]),
#  array([-5, -1,  3, -4]),
#  array([-5, -1,  3, -3]),
#  array([-5, -1,  3, -2]),
#  array([-5, -1,  3, -1]),
#  array([-5, -1,  3,  0]),
#  array([-5, -1,  3,  1]),
#  array([-5, -1,  3,  2]),
#  array([-5, -1,  3,  3]),
#  array([-5, -1,  3,  4]),
#  array([-5, -1,  3,  5]),
#  array([-5, -1,  4, -5]),
#  array([-5, -1,  4, -4]),
#  array([-5, -1,  4, -3]),
#  array([-5, -1,  4, -2]),
#  array([-5, -1,  4, -1]),
#  array([-5, -1,  4,  0]),
#  array([-5, -1,  4,  1]),
#  array([-5, -1,  4,  2]),
#  array([-5, -1,  4,  3]),
#  array([-5, -1,  4,  4]),
#  array([-5, -1,  4,  5]),
#  array([-5, -1,  5, -5]),
#  array([-5, -1,  5, -4]),
#  array([-5, -1,  5, -3]),
#  array([-5, -1,  5, -2]),
#  array([-5, -1,  5, -1]),
#  array([-5, -1,  5,  0]),
#  array([-5, -1,  5,  1]),
#  array([-5, -1,  5,  2]),
#  array([-5, -1,  5,  3]),
#  array([-5, -1,  5,  4]),
#  array([-5, -1,  5,  5]),
#  array([-5,  0, -5, -5]),
#  array([-5,  0, -5, -4]),
#  array([-5,  0, -5, -3]),
#  array([-5,  0, -5, -2]),
#  array([-5,  0, -5, -1]),
#  array([-5,  0, -5,  0]),
#  array([-5,  0, -5,  1]),
#  array([-5,  0, -5,  2]),
#  array([-5,  0, -5,  3]),
#  array([-5,  0, -5,  4]),
#  array([-5,  0, -5,  5]),
#  array([-5,  0, -4, -5]),
#  array([-5,  0, -4, -4]),
#  array([-5,  0, -4, -3]),
#  array([-5,  0, -4, -2]),
#  array([-5,  0, -4, -1]),
#  array([-5,  0, -4,  0]),
#  array([-5,  0, -4,  1]),
#  array([-5,  0, -4,  2]),
#  array([-5,  0, -4,  3]),
#  array([-5,  0, -4,  4]),
#  array([-5,  0, -4,  5]),
#  array([-5,  0, -3, -5]),
#  array([-5,  0, -3, -4]),
#  array([-5,  0, -3, -3]),
#  array([-5,  0, -3, -2]),
#  array([-5,  0, -3, -1]),
#  array([-5,  0, -3,  0]),
#  array([-5,  0, -3,  1]),
#  array([-5,  0, -3,  2]),
#  array([-5,  0, -3,  3]),
#  array([-5,  0, -3,  4]),
#  array([-5,  0, -3,  5]),
#  array([-5,  0, -2, -5]),
#  array([-5,  0, -2, -4]),
#  array([-5,  0, -2, -3]),
#  array([-5,  0, -2, -2]),
#  array([-5,  0, -2, -1]),
#  array([-5,  0, -2,  0]),
#  array([-5,  0, -2,  1]),
#  array([-5,  0, -2,  2]),
#  array([-5,  0, -2,  3]),
#  array([-5,  0, -2,  4]),
#  array([-5,  0, -2,  5]),
#  array([-5,  0, -1, -5]),
#  array([-5,  0, -1, -4]),
#  array([-5,  0, -1, -3]),
#  array([-5,  0, -1, -2]),
#  array([-5,  0, -1, -1]),
#  array([-5,  0, -1,  0]),
#  array([-5,  0, -1,  1]),
#  array([-5,  0, -1,  2]),
#  array([-5,  0, -1,  3]),
#  array([-5,  0, -1,  4]),
#  array([-5,  0, -1,  5]),
#  array([-5,  0,  0, -5]),
#  array([-5,  0,  0, -4]),
#  array([-5,  0,  0, -3]),
#  array([-5,  0,  0, -2]),
#  array([-5,  0,  0, -1]),
#  array([-5,  0,  0,  0]),
#  array([-5,  0,  0,  1]),
#  array([-5,  0,  0,  2]),
#  array([-5,  0,  0,  3]),
#  array([-5,  0,  0,  4]),
#  array([-5,  0,  0,  5]),
#  array([-5,  0,  1, -5]),
#  array([-5,  0,  1, -4]),
#  array([-5,  0,  1, -3]),
#  array([-5,  0,  1, -2]),
#  array([-5,  0,  1, -1]),
#  array([-5,  0,  1,  0]),
#  array([-5,  0,  1,  1]),
#  array([-5,  0,  1,  2]),
#  array([-5,  0,  1,  3]),
#  array([-5,  0,  1,  4]),
#  array([-5,  0,  1,  5]),
#  array([-5,  0,  2, -5]),
#  array([-5,  0,  2, -4]),
#  array([-5,  0,  2, -3]),
#  array([-5,  0,  2, -2]),
#  array([-5,  0,  2, -1]),
#  array([-5,  0,  2,  0]),
#  array([-5,  0,  2,  1]),
#  array([-5,  0,  2,  2]),
#  array([-5,  0,  2,  3]),
#  array([-5,  0,  2,  4]),
#  array([-5,  0,  2,  5]),
#  array([-5,  0,  3, -5]),
#  array([-5,  0,  3, -4]),
#  array([-5,  0,  3, -3]),
#  array([-5,  0,  3, -2]),
#  array([-5,  0,  3, -1]),
#  array([-5,  0,  3,  0]),
#  array([-5,  0,  3,  1]),
#  array([-5,  0,  3,  2]),
#  array([-5,  0,  3,  3]),
#  array([-5,  0,  3,  4]),
#  array([-5,  0,  3,  5]),
#  array([-5,  0,  4, -5]),
#  array([-5,  0,  4, -4]),
#  array([-5,  0,  4, -3]),
#  array([-5,  0,  4, -2]),
#  array([-5,  0,  4, -1]),
#  array([-5,  0,  4,  0]),
#  array([-5,  0,  4,  1]),
#  array([-5,  0,  4,  2]),
#  array([-5,  0,  4,  3]),
#  array([-5,  0,  4,  4]),
#  array([-5,  0,  4,  5]),
#  array([-5,  0,  5, -5]),
#  array([-5,  0,  5, -4]),
#  array([-5,  0,  5, -3]),
#  array([-5,  0,  5, -2]),
#  array([-5,  0,  5, -1]),
#  array([-5,  0,  5,  0]),
#  array([-5,  0,  5,  1]),
#  array([-5,  0,  5,  2]),
#  array([-5,  0,  5,  3]),
#  array([-5,  0,  5,  4]),
#  array([-5,  0,  5,  5]),
#  array([-5,  1, -5, -5]),
#  array([-5,  1, -5, -4]),
#  array([-5,  1, -5, -3]),
#  array([-5,  1, -5, -2]),
#  array([-5,  1, -5, -1]),
#  array([-5,  1, -5,  0]),
#  array([-5,  1, -5,  1]),
#  array([-5,  1, -5,  2]),
#  array([-5,  1, -5,  3]),
#  array([-5,  1, -5,  4]),
#  array([-5,  1, -5,  5]),
#  array([-5,  1, -4, -5]),
#  array([-5,  1, -4, -4]),
#  array([-5,  1, -4, -3]),
#  array([-5,  1, -4, -2]),
#  array([-5,  1, -4, -1]),
#  array([-5,  1, -4,  0]),
#  array([-5,  1, -4,  1]),
#  array([-5,  1, -4,  2]),
#  array([-5,  1, -4,  3]),
#  array([-5,  1, -4,  4]),
#  array([-5,  1, -4,  5]),
#  array([-5,  1, -3, -5]),
#  array([-5,  1, -3, -4]),
#  array([-5,  1, -3, -3]),
#  array([-5,  1, -3, -2]),
#  array([-5,  1, -3, -1]),
#  array([-5,  1, -3,  0]),
#  array([-5,  1, -3,  1]),
#  array([-5,  1, -3,  2]),
#  array([-5,  1, -3,  3]),
#  array([-5,  1, -3,  4]),
#  array([-5,  1, -3,  5]),
#  array([-5,  1, -2, -5]),
#  array([-5,  1, -2, -4]),
#  array([-5,  1, -2, -3]),
#  array([-5,  1, -2, -2]),
#  array([-5,  1, -2, -1]),
#  array([-5,  1, -2,  0]),
#  array([-5,  1, -2,  1]),
#  array([-5,  1, -2,  2]),
#  array([-5,  1, -2,  3]),
#  array([-5,  1, -2,  4]),
#  array([-5,  1, -2,  5]),
#  array([-5,  1, -1, -5]),
#  array([-5,  1, -1, -4]),
#  array([-5,  1, -1, -3]),
#  array([-5,  1, -1, -2]),
#  array([-5,  1, -1, -1]),
#  array([-5,  1, -1,  0]),
#  array([-5,  1, -1,  1]),
#  array([-5,  1, -1,  2]),
#  array([-5,  1, -1,  3]),
#  array([-5,  1, -1,  4]),
#  array([-5,  1, -1,  5]),
#  array([-5,  1,  0, -5]),
#  array([-5,  1,  0, -4]),
#  array([-5,  1,  0, -3]),
#  array([-5,  1,  0, -2]),
#  array([-5,  1,  0, -1]),
#  array([-5,  1,  0,  0]),
#  array([-5,  1,  0,  1]),
#  array([-5,  1,  0,  2]),
#  array([-5,  1,  0,  3]),
#  array([-5,  1,  0,  4]),
#  array([-5,  1,  0,  5]),
#  array([-5,  1,  1, -5]),
#  array([-5,  1,  1, -4]),
#  array([-5,  1,  1, -3]),
#  array([-5,  1,  1, -2]),
#  array([-5,  1,  1, -1]),
#  array([-5,  1,  1,  0]),
#  array([-5,  1,  1,  1]),
#  array([-5,  1,  1,  2]),
#  array([-5,  1,  1,  3]),
#  array([-5,  1,  1,  4]),
#  array([-5,  1,  1,  5]),
#  array([-5,  1,  2, -5]),
#  array([-5,  1,  2, -4]),
#  array([-5,  1,  2, -3]),
#  array([-5,  1,  2, -2]),
#  array([-5,  1,  2, -1]),
#  array([-5,  1,  2,  0]),
#  array([-5,  1,  2,  1]),
#  array([-5,  1,  2,  2]),
#  array([-5,  1,  2,  3]),
#  array([-5,  1,  2,  4]),
#  array([-5,  1,  2,  5]),
#  array([-5,  1,  3, -5]),
#  array([-5,  1,  3, -4]),
#  array([-5,  1,  3, -3]),
#  array([-5,  1,  3, -2]),
#  array([-5,  1,  3, -1]),
#  array([-5,  1,  3,  0]),
#  array([-5,  1,  3,  1]),
#  array([-5,  1,  3,  2]),
#  array([-5,  1,  3,  3]),
#  array([-5,  1,  3,  4]),
#  array([-5,  1,  3,  5]),
#  array([-5,  1,  4, -5]),
#  array([-5,  1,  4, -4]),
#  array([-5,  1,  4, -3]),
#  array([-5,  1,  4, -2]),
#  array([-5,  1,  4, -1]),
#  array([-5,  1,  4,  0]),
#  array([-5,  1,  4,  1]),
#  array([-5,  1,  4,  2]),
#  array([-5,  1,  4,  3]),
#  array([-5,  1,  4,  4]),
#  array([-5,  1,  4,  5]),
#  array([-5,  1,  5, -5]),
#  array([-5,  1,  5, -4]),
#  array([-5,  1,  5, -3]),
#  array([-5,  1,  5, -2]),
#  array([-5,  1,  5, -1]),
#  array([-5,  1,  5,  0]),
#  array([-5,  1,  5,  1]),
#  array([-5,  1,  5,  2]),
#  array([-5,  1,  5,  3]),
#  array([-5,  1,  5,  4]),
#  array([-5,  1,  5,  5]),
#  array([-5,  2, -5, -5]),
#  array([-5,  2, -5, -4]),
#  array([-5,  2, -5, -3]),
#  array([-5,  2, -5, -2]),
#  array([-5,  2, -5, -1]),
#  array([-5,  2, -5,  0]),
#  array([-5,  2, -5,  1]),
#  array([-5,  2, -5,  2]),
#  array([-5,  2, -5,  3]),
#  array([-5,  2, -5,  4]),
#  array([-5,  2, -5,  5]),
#  array([-5,  2, -4, -5]),
#  array([-5,  2, -4, -4]),
#  array([-5,  2, -4, -3]),
#  array([-5,  2, -4, -2]),
#  array([-5,  2, -4, -1]),
#  array([-5,  2, -4,  0]),
#  array([-5,  2, -4,  1]),
#  array([-5,  2, -4,  2]),
#  array([-5,  2, -4,  3]),
#  array([-5,  2, -4,  4]),
#  array([-5,  2, -4,  5]),
#  array([-5,  2, -3, -5]),
#  array([-5,  2, -3, -4]),
#  array([-5,  2, -3, -3]),
#  array([-5,  2, -3, -2]),
#  array([-5,  2, -3, -1]),
#  array([-5,  2, -3,  0]),
#  array([-5,  2, -3,  1]),
#  array([-5,  2, -3,  2]),
#  array([-5,  2, -3,  3]),
#  array([-5,  2, -3,  4]),
#  array([-5,  2, -3,  5]),
#  array([-5,  2, -2, -5]),
#  array([-5,  2, -2, -4]),
#  array([-5,  2, -2, -3]),
#  array([-5,  2, -2, -2]),
#  array([-5,  2, -2, -1]),
#  array([-5,  2, -2,  0]),
#  array([-5,  2, -2,  1]),
#  array([-5,  2, -2,  2]),
#  array([-5,  2, -2,  3]),
#  array([-5,  2, -2,  4]),
#  array([-5,  2, -2,  5]),
#  array([-5,  2, -1, -5]),
#  array([-5,  2, -1, -4]),
#  array([-5,  2, -1, -3]),
#  array([-5,  2, -1, -2]),
#  array([-5,  2, -1, -1]),
#  array([-5,  2, -1,  0]),
#  array([-5,  2, -1,  1]),
#  array([-5,  2, -1,  2]),
#  array([-5,  2, -1,  3]),
#  array([-5,  2, -1,  4]),
#  array([-5,  2, -1,  5]),
#  array([-5,  2,  0, -5]),
#  array([-5,  2,  0, -4]),
#  array([-5,  2,  0, -3]),
#  array([-5,  2,  0, -2]),
#  array([-5,  2,  0, -1]),
#  array([-5,  2,  0,  0]),
#  array([-5,  2,  0,  1]),
#  array([-5,  2,  0,  2]),
#  array([-5,  2,  0,  3]),
#  array([-5,  2,  0,  4]),
#  array([-5,  2,  0,  5]),
#  array([-5,  2,  1, -5]),
#  array([-5,  2,  1, -4]),
#  array([-5,  2,  1, -3]),
#  array([-5,  2,  1, -2]),
#  array([-5,  2,  1, -1]),
#  array([-5,  2,  1,  0]),
#  array([-5,  2,  1,  1]),
#  array([-5,  2,  1,  2]),
#  array([-5,  2,  1,  3]),
#  array([-5,  2,  1,  4]),
#  array([-5,  2,  1,  5]),
#  array([-5,  2,  2, -5]),
#  array([-5,  2,  2, -4]),
#  array([-5,  2,  2, -3]),
#  array([-5,  2,  2, -2]),
#  array([-5,  2,  2, -1]),
#  array([-5,  2,  2,  0]),
#  array([-5,  2,  2,  1]),
#  array([-5,  2,  2,  2]),
#  array([-5,  2,  2,  3]),
#  array([-5,  2,  2,  4]),
#  array([-5,  2,  2,  5]),
#  array([-5,  2,  3, -5]),
#  array([-5,  2,  3, -4]),
#  array([-5,  2,  3, -3]),
#  array([-5,  2,  3, -2]),
#  array([-5,  2,  3, -1]),
#  array([-5,  2,  3,  0]),
#  array([-5,  2,  3,  1]),
#  array([-5,  2,  3,  2]),
#  array([-5,  2,  3,  3]),
#  array([-5,  2,  3,  4]),
#  array([-5,  2,  3,  5]),
#  array([-5,  2,  4, -5]),
#  array([-5,  2,  4, -4]),
#  array([-5,  2,  4, -3]),
#  array([-5,  2,  4, -2]),
#  array([-5,  2,  4, -1]),
#  array([-5,  2,  4,  0]),
#  array([-5,  2,  4,  1]),
#  array([-5,  2,  4,  2]),
#  array([-5,  2,  4,  3]),
#  array([-5,  2,  4,  4]),
#  array([-5,  2,  4,  5]),
#  array([-5,  2,  5, -5]),
#  array([-5,  2,  5, -4]),
#  array([-5,  2,  5, -3]),
#  array([-5,  2,  5, -2]),
#  array([-5,  2,  5, -1]),
#  array([-5,  2,  5,  0]),
#  array([-5,  2,  5,  1]),
#  array([-5,  2,  5,  2]),
#  array([-5,  2,  5,  3]),
#  array([-5,  2,  5,  4]),
#  array([-5,  2,  5,  5]),
#  array([-5,  3, -5, -5]),
#  array([-5,  3, -5, -4]),
#  array([-5,  3, -5, -3]),
#  array([-5,  3, -5, -2]),
#  array([-5,  3, -5, -1]),
#  array([-5,  3, -5,  0]),
#  array([-5,  3, -5,  1]),
#  array([-5,  3, -5,  2]),
#  array([-5,  3, -5,  3]),
#  array([-5,  3, -5,  4]),
#  array([-5,  3, -5,  5]),
#  array([-5,  3, -4, -5]),
#  array([-5,  3, -4, -4]),
#  array([-5,  3, -4, -3]),
#  array([-5,  3, -4, -2]),
#  array([-5,  3, -4, -1]),
#  array([-5,  3, -4,  0]),
#  array([-5,  3, -4,  1]),
#  array([-5,  3, -4,  2]),
#  array([-5,  3, -4,  3]),
#  array([-5,  3, -4,  4]),
#  array([-5,  3, -4,  5]),
#  array([-5,  3, -3, -5]),
#  array([-5,  3, -3, -4]),
#  array([-5,  3, -3, -3]),
#  array([-5,  3, -3, -2]),
#  array([-5,  3, -3, -1]),
#  array([-5,  3, -3,  0]),
#  array([-5,  3, -3,  1]),
#  array([-5,  3, -3,  2]),
#  array([-5,  3, -3,  3]),
#  array([-5,  3, -3,  4]),
#  ...]

# %%
from itertools import product
from itertools import combinations_with_replacement as comb

sc_cands2 = [np.array(tup) for tup in product(*[range(-max_R, max_R + 1) for i in range(dim_r)])]
sc_cands2
# Out:
# [array([-5, -5, -5, -5]),
#  array([-5, -5, -5, -4]),
#  array([-5, -5, -5, -3]),
#  array([-5, -5, -5, -2]),
#  array([-5, -5, -5, -1]),
#  array([-5, -5, -5,  0]),
#  array([-5, -5, -5,  1]),
#  array([-5, -5, -5,  2]),
#  array([-5, -5, -5,  3]),
#  array([-5, -5, -5,  4]),
#  array([-5, -5, -5,  5]),
#  array([-5, -5, -4, -5]),
#  array([-5, -5, -4, -4]),
#  array([-5, -5, -4, -3]),
#  array([-5, -5, -4, -2]),
#  array([-5, -5, -4, -1]),
#  array([-5, -5, -4,  0]),
#  array([-5, -5, -4,  1]),
#  array([-5, -5, -4,  2]),
#  array([-5, -5, -4,  3]),
#  array([-5, -5, -4,  4]),
#  array([-5, -5, -4,  5]),
#  array([-5, -5, -3, -5]),
#  array([-5, -5, -3, -4]),
#  array([-5, -5, -3, -3]),
#  array([-5, -5, -3, -2]),
#  array([-5, -5, -3, -1]),
#  array([-5, -5, -3,  0]),
#  array([-5, -5, -3,  1]),
#  array([-5, -5, -3,  2]),
#  array([-5, -5, -3,  3]),
#  array([-5, -5, -3,  4]),
#  array([-5, -5, -3,  5]),
#  array([-5, -5, -2, -5]),
#  array([-5, -5, -2, -4]),
#  array([-5, -5, -2, -3]),
#  array([-5, -5, -2, -2]),
#  array([-5, -5, -2, -1]),
#  array([-5, -5, -2,  0]),
#  array([-5, -5, -2,  1]),
#  array([-5, -5, -2,  2]),
#  array([-5, -5, -2,  3]),
#  array([-5, -5, -2,  4]),
#  array([-5, -5, -2,  5]),
#  array([-5, -5, -1, -5]),
#  array([-5, -5, -1, -4]),
#  array([-5, -5, -1, -3]),
#  array([-5, -5, -1, -2]),
#  array([-5, -5, -1, -1]),
#  array([-5, -5, -1,  0]),
#  array([-5, -5, -1,  1]),
#  array([-5, -5, -1,  2]),
#  array([-5, -5, -1,  3]),
#  array([-5, -5, -1,  4]),
#  array([-5, -5, -1,  5]),
#  array([-5, -5,  0, -5]),
#  array([-5, -5,  0, -4]),
#  array([-5, -5,  0, -3]),
#  array([-5, -5,  0, -2]),
#  array([-5, -5,  0, -1]),
#  array([-5, -5,  0,  0]),
#  array([-5, -5,  0,  1]),
#  array([-5, -5,  0,  2]),
#  array([-5, -5,  0,  3]),
#  array([-5, -5,  0,  4]),
#  array([-5, -5,  0,  5]),
#  array([-5, -5,  1, -5]),
#  array([-5, -5,  1, -4]),
#  array([-5, -5,  1, -3]),
#  array([-5, -5,  1, -2]),
#  array([-5, -5,  1, -1]),
#  array([-5, -5,  1,  0]),
#  array([-5, -5,  1,  1]),
#  array([-5, -5,  1,  2]),
#  array([-5, -5,  1,  3]),
#  array([-5, -5,  1,  4]),
#  array([-5, -5,  1,  5]),
#  array([-5, -5,  2, -5]),
#  array([-5, -5,  2, -4]),
#  array([-5, -5,  2, -3]),
#  array([-5, -5,  2, -2]),
#  array([-5, -5,  2, -1]),
#  array([-5, -5,  2,  0]),
#  array([-5, -5,  2,  1]),
#  array([-5, -5,  2,  2]),
#  array([-5, -5,  2,  3]),
#  array([-5, -5,  2,  4]),
#  array([-5, -5,  2,  5]),
#  array([-5, -5,  3, -5]),
#  array([-5, -5,  3, -4]),
#  array([-5, -5,  3, -3]),
#  array([-5, -5,  3, -2]),
#  array([-5, -5,  3, -1]),
#  array([-5, -5,  3,  0]),
#  array([-5, -5,  3,  1]),
#  array([-5, -5,  3,  2]),
#  array([-5, -5,  3,  3]),
#  array([-5, -5,  3,  4]),
#  array([-5, -5,  3,  5]),
#  array([-5, -5,  4, -5]),
#  array([-5, -5,  4, -4]),
#  array([-5, -5,  4, -3]),
#  array([-5, -5,  4, -2]),
#  array([-5, -5,  4, -1]),
#  array([-5, -5,  4,  0]),
#  array([-5, -5,  4,  1]),
#  array([-5, -5,  4,  2]),
#  array([-5, -5,  4,  3]),
#  array([-5, -5,  4,  4]),
#  array([-5, -5,  4,  5]),
#  array([-5, -5,  5, -5]),
#  array([-5, -5,  5, -4]),
#  array([-5, -5,  5, -3]),
#  array([-5, -5,  5, -2]),
#  array([-5, -5,  5, -1]),
#  array([-5, -5,  5,  0]),
#  array([-5, -5,  5,  1]),
#  array([-5, -5,  5,  2]),
#  array([-5, -5,  5,  3]),
#  array([-5, -5,  5,  4]),
#  array([-5, -5,  5,  5]),
#  array([-5, -4, -5, -5]),
#  array([-5, -4, -5, -4]),
#  array([-5, -4, -5, -3]),
#  array([-5, -4, -5, -2]),
#  array([-5, -4, -5, -1]),
#  array([-5, -4, -5,  0]),
#  array([-5, -4, -5,  1]),
#  array([-5, -4, -5,  2]),
#  array([-5, -4, -5,  3]),
#  array([-5, -4, -5,  4]),
#  array([-5, -4, -5,  5]),
#  array([-5, -4, -4, -5]),
#  array([-5, -4, -4, -4]),
#  array([-5, -4, -4, -3]),
#  array([-5, -4, -4, -2]),
#  array([-5, -4, -4, -1]),
#  array([-5, -4, -4,  0]),
#  array([-5, -4, -4,  1]),
#  array([-5, -4, -4,  2]),
#  array([-5, -4, -4,  3]),
#  array([-5, -4, -4,  4]),
#  array([-5, -4, -4,  5]),
#  array([-5, -4, -3, -5]),
#  array([-5, -4, -3, -4]),
#  array([-5, -4, -3, -3]),
#  array([-5, -4, -3, -2]),
#  array([-5, -4, -3, -1]),
#  array([-5, -4, -3,  0]),
#  array([-5, -4, -3,  1]),
#  array([-5, -4, -3,  2]),
#  array([-5, -4, -3,  3]),
#  array([-5, -4, -3,  4]),
#  array([-5, -4, -3,  5]),
#  array([-5, -4, -2, -5]),
#  array([-5, -4, -2, -4]),
#  array([-5, -4, -2, -3]),
#  array([-5, -4, -2, -2]),
#  array([-5, -4, -2, -1]),
#  array([-5, -4, -2,  0]),
#  array([-5, -4, -2,  1]),
#  array([-5, -4, -2,  2]),
#  array([-5, -4, -2,  3]),
#  array([-5, -4, -2,  4]),
#  array([-5, -4, -2,  5]),
#  array([-5, -4, -1, -5]),
#  array([-5, -4, -1, -4]),
#  array([-5, -4, -1, -3]),
#  array([-5, -4, -1, -2]),
#  array([-5, -4, -1, -1]),
#  array([-5, -4, -1,  0]),
#  array([-5, -4, -1,  1]),
#  array([-5, -4, -1,  2]),
#  array([-5, -4, -1,  3]),
#  array([-5, -4, -1,  4]),
#  array([-5, -4, -1,  5]),
#  array([-5, -4,  0, -5]),
#  array([-5, -4,  0, -4]),
#  array([-5, -4,  0, -3]),
#  array([-5, -4,  0, -2]),
#  array([-5, -4,  0, -1]),
#  array([-5, -4,  0,  0]),
#  array([-5, -4,  0,  1]),
#  array([-5, -4,  0,  2]),
#  array([-5, -4,  0,  3]),
#  array([-5, -4,  0,  4]),
#  array([-5, -4,  0,  5]),
#  array([-5, -4,  1, -5]),
#  array([-5, -4,  1, -4]),
#  array([-5, -4,  1, -3]),
#  array([-5, -4,  1, -2]),
#  array([-5, -4,  1, -1]),
#  array([-5, -4,  1,  0]),
#  array([-5, -4,  1,  1]),
#  array([-5, -4,  1,  2]),
#  array([-5, -4,  1,  3]),
#  array([-5, -4,  1,  4]),
#  array([-5, -4,  1,  5]),
#  array([-5, -4,  2, -5]),
#  array([-5, -4,  2, -4]),
#  array([-5, -4,  2, -3]),
#  array([-5, -4,  2, -2]),
#  array([-5, -4,  2, -1]),
#  array([-5, -4,  2,  0]),
#  array([-5, -4,  2,  1]),
#  array([-5, -4,  2,  2]),
#  array([-5, -4,  2,  3]),
#  array([-5, -4,  2,  4]),
#  array([-5, -4,  2,  5]),
#  array([-5, -4,  3, -5]),
#  array([-5, -4,  3, -4]),
#  array([-5, -4,  3, -3]),
#  array([-5, -4,  3, -2]),
#  array([-5, -4,  3, -1]),
#  array([-5, -4,  3,  0]),
#  array([-5, -4,  3,  1]),
#  array([-5, -4,  3,  2]),
#  array([-5, -4,  3,  3]),
#  array([-5, -4,  3,  4]),
#  array([-5, -4,  3,  5]),
#  array([-5, -4,  4, -5]),
#  array([-5, -4,  4, -4]),
#  array([-5, -4,  4, -3]),
#  array([-5, -4,  4, -2]),
#  array([-5, -4,  4, -1]),
#  array([-5, -4,  4,  0]),
#  array([-5, -4,  4,  1]),
#  array([-5, -4,  4,  2]),
#  array([-5, -4,  4,  3]),
#  array([-5, -4,  4,  4]),
#  array([-5, -4,  4,  5]),
#  array([-5, -4,  5, -5]),
#  array([-5, -4,  5, -4]),
#  array([-5, -4,  5, -3]),
#  array([-5, -4,  5, -2]),
#  array([-5, -4,  5, -1]),
#  array([-5, -4,  5,  0]),
#  array([-5, -4,  5,  1]),
#  array([-5, -4,  5,  2]),
#  array([-5, -4,  5,  3]),
#  array([-5, -4,  5,  4]),
#  array([-5, -4,  5,  5]),
#  array([-5, -3, -5, -5]),
#  array([-5, -3, -5, -4]),
#  array([-5, -3, -5, -3]),
#  array([-5, -3, -5, -2]),
#  array([-5, -3, -5, -1]),
#  array([-5, -3, -5,  0]),
#  array([-5, -3, -5,  1]),
#  array([-5, -3, -5,  2]),
#  array([-5, -3, -5,  3]),
#  array([-5, -3, -5,  4]),
#  array([-5, -3, -5,  5]),
#  array([-5, -3, -4, -5]),
#  array([-5, -3, -4, -4]),
#  array([-5, -3, -4, -3]),
#  array([-5, -3, -4, -2]),
#  array([-5, -3, -4, -1]),
#  array([-5, -3, -4,  0]),
#  array([-5, -3, -4,  1]),
#  array([-5, -3, -4,  2]),
#  array([-5, -3, -4,  3]),
#  array([-5, -3, -4,  4]),
#  array([-5, -3, -4,  5]),
#  array([-5, -3, -3, -5]),
#  array([-5, -3, -3, -4]),
#  array([-5, -3, -3, -3]),
#  array([-5, -3, -3, -2]),
#  array([-5, -3, -3, -1]),
#  array([-5, -3, -3,  0]),
#  array([-5, -3, -3,  1]),
#  array([-5, -3, -3,  2]),
#  array([-5, -3, -3,  3]),
#  array([-5, -3, -3,  4]),
#  array([-5, -3, -3,  5]),
#  array([-5, -3, -2, -5]),
#  array([-5, -3, -2, -4]),
#  array([-5, -3, -2, -3]),
#  array([-5, -3, -2, -2]),
#  array([-5, -3, -2, -1]),
#  array([-5, -3, -2,  0]),
#  array([-5, -3, -2,  1]),
#  array([-5, -3, -2,  2]),
#  array([-5, -3, -2,  3]),
#  array([-5, -3, -2,  4]),
#  array([-5, -3, -2,  5]),
#  array([-5, -3, -1, -5]),
#  array([-5, -3, -1, -4]),
#  array([-5, -3, -1, -3]),
#  array([-5, -3, -1, -2]),
#  array([-5, -3, -1, -1]),
#  array([-5, -3, -1,  0]),
#  array([-5, -3, -1,  1]),
#  array([-5, -3, -1,  2]),
#  array([-5, -3, -1,  3]),
#  array([-5, -3, -1,  4]),
#  array([-5, -3, -1,  5]),
#  array([-5, -3,  0, -5]),
#  array([-5, -3,  0, -4]),
#  array([-5, -3,  0, -3]),
#  array([-5, -3,  0, -2]),
#  array([-5, -3,  0, -1]),
#  array([-5, -3,  0,  0]),
#  array([-5, -3,  0,  1]),
#  array([-5, -3,  0,  2]),
#  array([-5, -3,  0,  3]),
#  array([-5, -3,  0,  4]),
#  array([-5, -3,  0,  5]),
#  array([-5, -3,  1, -5]),
#  array([-5, -3,  1, -4]),
#  array([-5, -3,  1, -3]),
#  array([-5, -3,  1, -2]),
#  array([-5, -3,  1, -1]),
#  array([-5, -3,  1,  0]),
#  array([-5, -3,  1,  1]),
#  array([-5, -3,  1,  2]),
#  array([-5, -3,  1,  3]),
#  array([-5, -3,  1,  4]),
#  array([-5, -3,  1,  5]),
#  array([-5, -3,  2, -5]),
#  array([-5, -3,  2, -4]),
#  array([-5, -3,  2, -3]),
#  array([-5, -3,  2, -2]),
#  array([-5, -3,  2, -1]),
#  array([-5, -3,  2,  0]),
#  array([-5, -3,  2,  1]),
#  array([-5, -3,  2,  2]),
#  array([-5, -3,  2,  3]),
#  array([-5, -3,  2,  4]),
#  array([-5, -3,  2,  5]),
#  array([-5, -3,  3, -5]),
#  array([-5, -3,  3, -4]),
#  array([-5, -3,  3, -3]),
#  array([-5, -3,  3, -2]),
#  array([-5, -3,  3, -1]),
#  array([-5, -3,  3,  0]),
#  array([-5, -3,  3,  1]),
#  array([-5, -3,  3,  2]),
#  array([-5, -3,  3,  3]),
#  array([-5, -3,  3,  4]),
#  array([-5, -3,  3,  5]),
#  array([-5, -3,  4, -5]),
#  array([-5, -3,  4, -4]),
#  array([-5, -3,  4, -3]),
#  array([-5, -3,  4, -2]),
#  array([-5, -3,  4, -1]),
#  array([-5, -3,  4,  0]),
#  array([-5, -3,  4,  1]),
#  array([-5, -3,  4,  2]),
#  array([-5, -3,  4,  3]),
#  array([-5, -3,  4,  4]),
#  array([-5, -3,  4,  5]),
#  array([-5, -3,  5, -5]),
#  array([-5, -3,  5, -4]),
#  array([-5, -3,  5, -3]),
#  array([-5, -3,  5, -2]),
#  array([-5, -3,  5, -1]),
#  array([-5, -3,  5,  0]),
#  array([-5, -3,  5,  1]),
#  array([-5, -3,  5,  2]),
#  array([-5, -3,  5,  3]),
#  array([-5, -3,  5,  4]),
#  array([-5, -3,  5,  5]),
#  array([-5, -2, -5, -5]),
#  array([-5, -2, -5, -4]),
#  array([-5, -2, -5, -3]),
#  array([-5, -2, -5, -2]),
#  array([-5, -2, -5, -1]),
#  array([-5, -2, -5,  0]),
#  array([-5, -2, -5,  1]),
#  array([-5, -2, -5,  2]),
#  array([-5, -2, -5,  3]),
#  array([-5, -2, -5,  4]),
#  array([-5, -2, -5,  5]),
#  array([-5, -2, -4, -5]),
#  array([-5, -2, -4, -4]),
#  array([-5, -2, -4, -3]),
#  array([-5, -2, -4, -2]),
#  array([-5, -2, -4, -1]),
#  array([-5, -2, -4,  0]),
#  array([-5, -2, -4,  1]),
#  array([-5, -2, -4,  2]),
#  array([-5, -2, -4,  3]),
#  array([-5, -2, -4,  4]),
#  array([-5, -2, -4,  5]),
#  array([-5, -2, -3, -5]),
#  array([-5, -2, -3, -4]),
#  array([-5, -2, -3, -3]),
#  array([-5, -2, -3, -2]),
#  array([-5, -2, -3, -1]),
#  array([-5, -2, -3,  0]),
#  array([-5, -2, -3,  1]),
#  array([-5, -2, -3,  2]),
#  array([-5, -2, -3,  3]),
#  array([-5, -2, -3,  4]),
#  array([-5, -2, -3,  5]),
#  array([-5, -2, -2, -5]),
#  array([-5, -2, -2, -4]),
#  array([-5, -2, -2, -3]),
#  array([-5, -2, -2, -2]),
#  array([-5, -2, -2, -1]),
#  array([-5, -2, -2,  0]),
#  array([-5, -2, -2,  1]),
#  array([-5, -2, -2,  2]),
#  array([-5, -2, -2,  3]),
#  array([-5, -2, -2,  4]),
#  array([-5, -2, -2,  5]),
#  array([-5, -2, -1, -5]),
#  array([-5, -2, -1, -4]),
#  array([-5, -2, -1, -3]),
#  array([-5, -2, -1, -2]),
#  array([-5, -2, -1, -1]),
#  array([-5, -2, -1,  0]),
#  array([-5, -2, -1,  1]),
#  array([-5, -2, -1,  2]),
#  array([-5, -2, -1,  3]),
#  array([-5, -2, -1,  4]),
#  array([-5, -2, -1,  5]),
#  array([-5, -2,  0, -5]),
#  array([-5, -2,  0, -4]),
#  array([-5, -2,  0, -3]),
#  array([-5, -2,  0, -2]),
#  array([-5, -2,  0, -1]),
#  array([-5, -2,  0,  0]),
#  array([-5, -2,  0,  1]),
#  array([-5, -2,  0,  2]),
#  array([-5, -2,  0,  3]),
#  array([-5, -2,  0,  4]),
#  array([-5, -2,  0,  5]),
#  array([-5, -2,  1, -5]),
#  array([-5, -2,  1, -4]),
#  array([-5, -2,  1, -3]),
#  array([-5, -2,  1, -2]),
#  array([-5, -2,  1, -1]),
#  array([-5, -2,  1,  0]),
#  array([-5, -2,  1,  1]),
#  array([-5, -2,  1,  2]),
#  array([-5, -2,  1,  3]),
#  array([-5, -2,  1,  4]),
#  array([-5, -2,  1,  5]),
#  array([-5, -2,  2, -5]),
#  array([-5, -2,  2, -4]),
#  array([-5, -2,  2, -3]),
#  array([-5, -2,  2, -2]),
#  array([-5, -2,  2, -1]),
#  array([-5, -2,  2,  0]),
#  array([-5, -2,  2,  1]),
#  array([-5, -2,  2,  2]),
#  array([-5, -2,  2,  3]),
#  array([-5, -2,  2,  4]),
#  array([-5, -2,  2,  5]),
#  array([-5, -2,  3, -5]),
#  array([-5, -2,  3, -4]),
#  array([-5, -2,  3, -3]),
#  array([-5, -2,  3, -2]),
#  array([-5, -2,  3, -1]),
#  array([-5, -2,  3,  0]),
#  array([-5, -2,  3,  1]),
#  array([-5, -2,  3,  2]),
#  array([-5, -2,  3,  3]),
#  array([-5, -2,  3,  4]),
#  array([-5, -2,  3,  5]),
#  array([-5, -2,  4, -5]),
#  array([-5, -2,  4, -4]),
#  array([-5, -2,  4, -3]),
#  array([-5, -2,  4, -2]),
#  array([-5, -2,  4, -1]),
#  array([-5, -2,  4,  0]),
#  array([-5, -2,  4,  1]),
#  array([-5, -2,  4,  2]),
#  array([-5, -2,  4,  3]),
#  array([-5, -2,  4,  4]),
#  array([-5, -2,  4,  5]),
#  array([-5, -2,  5, -5]),
#  array([-5, -2,  5, -4]),
#  array([-5, -2,  5, -3]),
#  array([-5, -2,  5, -2]),
#  array([-5, -2,  5, -1]),
#  array([-5, -2,  5,  0]),
#  array([-5, -2,  5,  1]),
#  array([-5, -2,  5,  2]),
#  array([-5, -2,  5,  3]),
#  array([-5, -2,  5,  4]),
#  array([-5, -2,  5,  5]),
#  array([-5, -1, -5, -5]),
#  array([-5, -1, -5, -4]),
#  array([-5, -1, -5, -3]),
#  array([-5, -1, -5, -2]),
#  array([-5, -1, -5, -1]),
#  array([-5, -1, -5,  0]),
#  array([-5, -1, -5,  1]),
#  array([-5, -1, -5,  2]),
#  array([-5, -1, -5,  3]),
#  array([-5, -1, -5,  4]),
#  array([-5, -1, -5,  5]),
#  array([-5, -1, -4, -5]),
#  array([-5, -1, -4, -4]),
#  array([-5, -1, -4, -3]),
#  array([-5, -1, -4, -2]),
#  array([-5, -1, -4, -1]),
#  array([-5, -1, -4,  0]),
#  array([-5, -1, -4,  1]),
#  array([-5, -1, -4,  2]),
#  array([-5, -1, -4,  3]),
#  array([-5, -1, -4,  4]),
#  array([-5, -1, -4,  5]),
#  array([-5, -1, -3, -5]),
#  array([-5, -1, -3, -4]),
#  array([-5, -1, -3, -3]),
#  array([-5, -1, -3, -2]),
#  array([-5, -1, -3, -1]),
#  array([-5, -1, -3,  0]),
#  array([-5, -1, -3,  1]),
#  array([-5, -1, -3,  2]),
#  array([-5, -1, -3,  3]),
#  array([-5, -1, -3,  4]),
#  array([-5, -1, -3,  5]),
#  array([-5, -1, -2, -5]),
#  array([-5, -1, -2, -4]),
#  array([-5, -1, -2, -3]),
#  array([-5, -1, -2, -2]),
#  array([-5, -1, -2, -1]),
#  array([-5, -1, -2,  0]),
#  array([-5, -1, -2,  1]),
#  array([-5, -1, -2,  2]),
#  array([-5, -1, -2,  3]),
#  array([-5, -1, -2,  4]),
#  array([-5, -1, -2,  5]),
#  array([-5, -1, -1, -5]),
#  array([-5, -1, -1, -4]),
#  array([-5, -1, -1, -3]),
#  array([-5, -1, -1, -2]),
#  array([-5, -1, -1, -1]),
#  array([-5, -1, -1,  0]),
#  array([-5, -1, -1,  1]),
#  array([-5, -1, -1,  2]),
#  array([-5, -1, -1,  3]),
#  array([-5, -1, -1,  4]),
#  array([-5, -1, -1,  5]),
#  array([-5, -1,  0, -5]),
#  array([-5, -1,  0, -4]),
#  array([-5, -1,  0, -3]),
#  array([-5, -1,  0, -2]),
#  array([-5, -1,  0, -1]),
#  array([-5, -1,  0,  0]),
#  array([-5, -1,  0,  1]),
#  array([-5, -1,  0,  2]),
#  array([-5, -1,  0,  3]),
#  array([-5, -1,  0,  4]),
#  array([-5, -1,  0,  5]),
#  array([-5, -1,  1, -5]),
#  array([-5, -1,  1, -4]),
#  array([-5, -1,  1, -3]),
#  array([-5, -1,  1, -2]),
#  array([-5, -1,  1, -1]),
#  array([-5, -1,  1,  0]),
#  array([-5, -1,  1,  1]),
#  array([-5, -1,  1,  2]),
#  array([-5, -1,  1,  3]),
#  array([-5, -1,  1,  4]),
#  array([-5, -1,  1,  5]),
#  array([-5, -1,  2, -5]),
#  array([-5, -1,  2, -4]),
#  array([-5, -1,  2, -3]),
#  array([-5, -1,  2, -2]),
#  array([-5, -1,  2, -1]),
#  array([-5, -1,  2,  0]),
#  array([-5, -1,  2,  1]),
#  array([-5, -1,  2,  2]),
#  array([-5, -1,  2,  3]),
#  array([-5, -1,  2,  4]),
#  array([-5, -1,  2,  5]),
#  array([-5, -1,  3, -5]),
#  array([-5, -1,  3, -4]),
#  array([-5, -1,  3, -3]),
#  array([-5, -1,  3, -2]),
#  array([-5, -1,  3, -1]),
#  array([-5, -1,  3,  0]),
#  array([-5, -1,  3,  1]),
#  array([-5, -1,  3,  2]),
#  array([-5, -1,  3,  3]),
#  array([-5, -1,  3,  4]),
#  array([-5, -1,  3,  5]),
#  array([-5, -1,  4, -5]),
#  array([-5, -1,  4, -4]),
#  array([-5, -1,  4, -3]),
#  array([-5, -1,  4, -2]),
#  array([-5, -1,  4, -1]),
#  array([-5, -1,  4,  0]),
#  array([-5, -1,  4,  1]),
#  array([-5, -1,  4,  2]),
#  array([-5, -1,  4,  3]),
#  array([-5, -1,  4,  4]),
#  array([-5, -1,  4,  5]),
#  array([-5, -1,  5, -5]),
#  array([-5, -1,  5, -4]),
#  array([-5, -1,  5, -3]),
#  array([-5, -1,  5, -2]),
#  array([-5, -1,  5, -1]),
#  array([-5, -1,  5,  0]),
#  array([-5, -1,  5,  1]),
#  array([-5, -1,  5,  2]),
#  array([-5, -1,  5,  3]),
#  array([-5, -1,  5,  4]),
#  array([-5, -1,  5,  5]),
#  array([-5,  0, -5, -5]),
#  array([-5,  0, -5, -4]),
#  array([-5,  0, -5, -3]),
#  array([-5,  0, -5, -2]),
#  array([-5,  0, -5, -1]),
#  array([-5,  0, -5,  0]),
#  array([-5,  0, -5,  1]),
#  array([-5,  0, -5,  2]),
#  array([-5,  0, -5,  3]),
#  array([-5,  0, -5,  4]),
#  array([-5,  0, -5,  5]),
#  array([-5,  0, -4, -5]),
#  array([-5,  0, -4, -4]),
#  array([-5,  0, -4, -3]),
#  array([-5,  0, -4, -2]),
#  array([-5,  0, -4, -1]),
#  array([-5,  0, -4,  0]),
#  array([-5,  0, -4,  1]),
#  array([-5,  0, -4,  2]),
#  array([-5,  0, -4,  3]),
#  array([-5,  0, -4,  4]),
#  array([-5,  0, -4,  5]),
#  array([-5,  0, -3, -5]),
#  array([-5,  0, -3, -4]),
#  array([-5,  0, -3, -3]),
#  array([-5,  0, -3, -2]),
#  array([-5,  0, -3, -1]),
#  array([-5,  0, -3,  0]),
#  array([-5,  0, -3,  1]),
#  array([-5,  0, -3,  2]),
#  array([-5,  0, -3,  3]),
#  array([-5,  0, -3,  4]),
#  array([-5,  0, -3,  5]),
#  array([-5,  0, -2, -5]),
#  array([-5,  0, -2, -4]),
#  array([-5,  0, -2, -3]),
#  array([-5,  0, -2, -2]),
#  array([-5,  0, -2, -1]),
#  array([-5,  0, -2,  0]),
#  array([-5,  0, -2,  1]),
#  array([-5,  0, -2,  2]),
#  array([-5,  0, -2,  3]),
#  array([-5,  0, -2,  4]),
#  array([-5,  0, -2,  5]),
#  array([-5,  0, -1, -5]),
#  array([-5,  0, -1, -4]),
#  array([-5,  0, -1, -3]),
#  array([-5,  0, -1, -2]),
#  array([-5,  0, -1, -1]),
#  array([-5,  0, -1,  0]),
#  array([-5,  0, -1,  1]),
#  array([-5,  0, -1,  2]),
#  array([-5,  0, -1,  3]),
#  array([-5,  0, -1,  4]),
#  array([-5,  0, -1,  5]),
#  array([-5,  0,  0, -5]),
#  array([-5,  0,  0, -4]),
#  array([-5,  0,  0, -3]),
#  array([-5,  0,  0, -2]),
#  array([-5,  0,  0, -1]),
#  array([-5,  0,  0,  0]),
#  array([-5,  0,  0,  1]),
#  array([-5,  0,  0,  2]),
#  array([-5,  0,  0,  3]),
#  array([-5,  0,  0,  4]),
#  array([-5,  0,  0,  5]),
#  array([-5,  0,  1, -5]),
#  array([-5,  0,  1, -4]),
#  array([-5,  0,  1, -3]),
#  array([-5,  0,  1, -2]),
#  array([-5,  0,  1, -1]),
#  array([-5,  0,  1,  0]),
#  array([-5,  0,  1,  1]),
#  array([-5,  0,  1,  2]),
#  array([-5,  0,  1,  3]),
#  array([-5,  0,  1,  4]),
#  array([-5,  0,  1,  5]),
#  array([-5,  0,  2, -5]),
#  array([-5,  0,  2, -4]),
#  array([-5,  0,  2, -3]),
#  array([-5,  0,  2, -2]),
#  array([-5,  0,  2, -1]),
#  array([-5,  0,  2,  0]),
#  array([-5,  0,  2,  1]),
#  array([-5,  0,  2,  2]),
#  array([-5,  0,  2,  3]),
#  array([-5,  0,  2,  4]),
#  array([-5,  0,  2,  5]),
#  array([-5,  0,  3, -5]),
#  array([-5,  0,  3, -4]),
#  array([-5,  0,  3, -3]),
#  array([-5,  0,  3, -2]),
#  array([-5,  0,  3, -1]),
#  array([-5,  0,  3,  0]),
#  array([-5,  0,  3,  1]),
#  array([-5,  0,  3,  2]),
#  array([-5,  0,  3,  3]),
#  array([-5,  0,  3,  4]),
#  array([-5,  0,  3,  5]),
#  array([-5,  0,  4, -5]),
#  array([-5,  0,  4, -4]),
#  array([-5,  0,  4, -3]),
#  array([-5,  0,  4, -2]),
#  array([-5,  0,  4, -1]),
#  array([-5,  0,  4,  0]),
#  array([-5,  0,  4,  1]),
#  array([-5,  0,  4,  2]),
#  array([-5,  0,  4,  3]),
#  array([-5,  0,  4,  4]),
#  array([-5,  0,  4,  5]),
#  array([-5,  0,  5, -5]),
#  array([-5,  0,  5, -4]),
#  array([-5,  0,  5, -3]),
#  array([-5,  0,  5, -2]),
#  array([-5,  0,  5, -1]),
#  array([-5,  0,  5,  0]),
#  array([-5,  0,  5,  1]),
#  array([-5,  0,  5,  2]),
#  array([-5,  0,  5,  3]),
#  array([-5,  0,  5,  4]),
#  array([-5,  0,  5,  5]),
#  array([-5,  1, -5, -5]),
#  array([-5,  1, -5, -4]),
#  array([-5,  1, -5, -3]),
#  array([-5,  1, -5, -2]),
#  array([-5,  1, -5, -1]),
#  array([-5,  1, -5,  0]),
#  array([-5,  1, -5,  1]),
#  array([-5,  1, -5,  2]),
#  array([-5,  1, -5,  3]),
#  array([-5,  1, -5,  4]),
#  array([-5,  1, -5,  5]),
#  array([-5,  1, -4, -5]),
#  array([-5,  1, -4, -4]),
#  array([-5,  1, -4, -3]),
#  array([-5,  1, -4, -2]),
#  array([-5,  1, -4, -1]),
#  array([-5,  1, -4,  0]),
#  array([-5,  1, -4,  1]),
#  array([-5,  1, -4,  2]),
#  array([-5,  1, -4,  3]),
#  array([-5,  1, -4,  4]),
#  array([-5,  1, -4,  5]),
#  array([-5,  1, -3, -5]),
#  array([-5,  1, -3, -4]),
#  array([-5,  1, -3, -3]),
#  array([-5,  1, -3, -2]),
#  array([-5,  1, -3, -1]),
#  array([-5,  1, -3,  0]),
#  array([-5,  1, -3,  1]),
#  array([-5,  1, -3,  2]),
#  array([-5,  1, -3,  3]),
#  array([-5,  1, -3,  4]),
#  array([-5,  1, -3,  5]),
#  array([-5,  1, -2, -5]),
#  array([-5,  1, -2, -4]),
#  array([-5,  1, -2, -3]),
#  array([-5,  1, -2, -2]),
#  array([-5,  1, -2, -1]),
#  array([-5,  1, -2,  0]),
#  array([-5,  1, -2,  1]),
#  array([-5,  1, -2,  2]),
#  array([-5,  1, -2,  3]),
#  array([-5,  1, -2,  4]),
#  array([-5,  1, -2,  5]),
#  array([-5,  1, -1, -5]),
#  array([-5,  1, -1, -4]),
#  array([-5,  1, -1, -3]),
#  array([-5,  1, -1, -2]),
#  array([-5,  1, -1, -1]),
#  array([-5,  1, -1,  0]),
#  array([-5,  1, -1,  1]),
#  array([-5,  1, -1,  2]),
#  array([-5,  1, -1,  3]),
#  array([-5,  1, -1,  4]),
#  array([-5,  1, -1,  5]),
#  array([-5,  1,  0, -5]),
#  array([-5,  1,  0, -4]),
#  array([-5,  1,  0, -3]),
#  array([-5,  1,  0, -2]),
#  array([-5,  1,  0, -1]),
#  array([-5,  1,  0,  0]),
#  array([-5,  1,  0,  1]),
#  array([-5,  1,  0,  2]),
#  array([-5,  1,  0,  3]),
#  array([-5,  1,  0,  4]),
#  array([-5,  1,  0,  5]),
#  array([-5,  1,  1, -5]),
#  array([-5,  1,  1, -4]),
#  array([-5,  1,  1, -3]),
#  array([-5,  1,  1, -2]),
#  array([-5,  1,  1, -1]),
#  array([-5,  1,  1,  0]),
#  array([-5,  1,  1,  1]),
#  array([-5,  1,  1,  2]),
#  array([-5,  1,  1,  3]),
#  array([-5,  1,  1,  4]),
#  array([-5,  1,  1,  5]),
#  array([-5,  1,  2, -5]),
#  array([-5,  1,  2, -4]),
#  array([-5,  1,  2, -3]),
#  array([-5,  1,  2, -2]),
#  array([-5,  1,  2, -1]),
#  array([-5,  1,  2,  0]),
#  array([-5,  1,  2,  1]),
#  array([-5,  1,  2,  2]),
#  array([-5,  1,  2,  3]),
#  array([-5,  1,  2,  4]),
#  array([-5,  1,  2,  5]),
#  array([-5,  1,  3, -5]),
#  array([-5,  1,  3, -4]),
#  array([-5,  1,  3, -3]),
#  array([-5,  1,  3, -2]),
#  array([-5,  1,  3, -1]),
#  array([-5,  1,  3,  0]),
#  array([-5,  1,  3,  1]),
#  array([-5,  1,  3,  2]),
#  array([-5,  1,  3,  3]),
#  array([-5,  1,  3,  4]),
#  array([-5,  1,  3,  5]),
#  array([-5,  1,  4, -5]),
#  array([-5,  1,  4, -4]),
#  array([-5,  1,  4, -3]),
#  array([-5,  1,  4, -2]),
#  array([-5,  1,  4, -1]),
#  array([-5,  1,  4,  0]),
#  array([-5,  1,  4,  1]),
#  array([-5,  1,  4,  2]),
#  array([-5,  1,  4,  3]),
#  array([-5,  1,  4,  4]),
#  array([-5,  1,  4,  5]),
#  array([-5,  1,  5, -5]),
#  array([-5,  1,  5, -4]),
#  array([-5,  1,  5, -3]),
#  array([-5,  1,  5, -2]),
#  array([-5,  1,  5, -1]),
#  array([-5,  1,  5,  0]),
#  array([-5,  1,  5,  1]),
#  array([-5,  1,  5,  2]),
#  array([-5,  1,  5,  3]),
#  array([-5,  1,  5,  4]),
#  array([-5,  1,  5,  5]),
#  array([-5,  2, -5, -5]),
#  array([-5,  2, -5, -4]),
#  array([-5,  2, -5, -3]),
#  array([-5,  2, -5, -2]),
#  array([-5,  2, -5, -1]),
#  array([-5,  2, -5,  0]),
#  array([-5,  2, -5,  1]),
#  array([-5,  2, -5,  2]),
#  array([-5,  2, -5,  3]),
#  array([-5,  2, -5,  4]),
#  array([-5,  2, -5,  5]),
#  array([-5,  2, -4, -5]),
#  array([-5,  2, -4, -4]),
#  array([-5,  2, -4, -3]),
#  array([-5,  2, -4, -2]),
#  array([-5,  2, -4, -1]),
#  array([-5,  2, -4,  0]),
#  array([-5,  2, -4,  1]),
#  array([-5,  2, -4,  2]),
#  array([-5,  2, -4,  3]),
#  array([-5,  2, -4,  4]),
#  array([-5,  2, -4,  5]),
#  array([-5,  2, -3, -5]),
#  array([-5,  2, -3, -4]),
#  array([-5,  2, -3, -3]),
#  array([-5,  2, -3, -2]),
#  array([-5,  2, -3, -1]),
#  array([-5,  2, -3,  0]),
#  array([-5,  2, -3,  1]),
#  array([-5,  2, -3,  2]),
#  array([-5,  2, -3,  3]),
#  array([-5,  2, -3,  4]),
#  array([-5,  2, -3,  5]),
#  array([-5,  2, -2, -5]),
#  array([-5,  2, -2, -4]),
#  array([-5,  2, -2, -3]),
#  array([-5,  2, -2, -2]),
#  array([-5,  2, -2, -1]),
#  array([-5,  2, -2,  0]),
#  array([-5,  2, -2,  1]),
#  array([-5,  2, -2,  2]),
#  array([-5,  2, -2,  3]),
#  array([-5,  2, -2,  4]),
#  array([-5,  2, -2,  5]),
#  array([-5,  2, -1, -5]),
#  array([-5,  2, -1, -4]),
#  array([-5,  2, -1, -3]),
#  array([-5,  2, -1, -2]),
#  array([-5,  2, -1, -1]),
#  array([-5,  2, -1,  0]),
#  array([-5,  2, -1,  1]),
#  array([-5,  2, -1,  2]),
#  array([-5,  2, -1,  3]),
#  array([-5,  2, -1,  4]),
#  array([-5,  2, -1,  5]),
#  array([-5,  2,  0, -5]),
#  array([-5,  2,  0, -4]),
#  array([-5,  2,  0, -3]),
#  array([-5,  2,  0, -2]),
#  array([-5,  2,  0, -1]),
#  array([-5,  2,  0,  0]),
#  array([-5,  2,  0,  1]),
#  array([-5,  2,  0,  2]),
#  array([-5,  2,  0,  3]),
#  array([-5,  2,  0,  4]),
#  array([-5,  2,  0,  5]),
#  array([-5,  2,  1, -5]),
#  array([-5,  2,  1, -4]),
#  array([-5,  2,  1, -3]),
#  array([-5,  2,  1, -2]),
#  array([-5,  2,  1, -1]),
#  array([-5,  2,  1,  0]),
#  array([-5,  2,  1,  1]),
#  array([-5,  2,  1,  2]),
#  array([-5,  2,  1,  3]),
#  array([-5,  2,  1,  4]),
#  array([-5,  2,  1,  5]),
#  array([-5,  2,  2, -5]),
#  array([-5,  2,  2, -4]),
#  array([-5,  2,  2, -3]),
#  array([-5,  2,  2, -2]),
#  array([-5,  2,  2, -1]),
#  array([-5,  2,  2,  0]),
#  array([-5,  2,  2,  1]),
#  array([-5,  2,  2,  2]),
#  array([-5,  2,  2,  3]),
#  array([-5,  2,  2,  4]),
#  array([-5,  2,  2,  5]),
#  array([-5,  2,  3, -5]),
#  array([-5,  2,  3, -4]),
#  array([-5,  2,  3, -3]),
#  array([-5,  2,  3, -2]),
#  array([-5,  2,  3, -1]),
#  array([-5,  2,  3,  0]),
#  array([-5,  2,  3,  1]),
#  array([-5,  2,  3,  2]),
#  array([-5,  2,  3,  3]),
#  array([-5,  2,  3,  4]),
#  array([-5,  2,  3,  5]),
#  array([-5,  2,  4, -5]),
#  array([-5,  2,  4, -4]),
#  array([-5,  2,  4, -3]),
#  array([-5,  2,  4, -2]),
#  array([-5,  2,  4, -1]),
#  array([-5,  2,  4,  0]),
#  array([-5,  2,  4,  1]),
#  array([-5,  2,  4,  2]),
#  array([-5,  2,  4,  3]),
#  array([-5,  2,  4,  4]),
#  array([-5,  2,  4,  5]),
#  array([-5,  2,  5, -5]),
#  array([-5,  2,  5, -4]),
#  array([-5,  2,  5, -3]),
#  array([-5,  2,  5, -2]),
#  array([-5,  2,  5, -1]),
#  array([-5,  2,  5,  0]),
#  array([-5,  2,  5,  1]),
#  array([-5,  2,  5,  2]),
#  array([-5,  2,  5,  3]),
#  array([-5,  2,  5,  4]),
#  array([-5,  2,  5,  5]),
#  array([-5,  3, -5, -5]),
#  array([-5,  3, -5, -4]),
#  array([-5,  3, -5, -3]),
#  array([-5,  3, -5, -2]),
#  array([-5,  3, -5, -1]),
#  array([-5,  3, -5,  0]),
#  array([-5,  3, -5,  1]),
#  array([-5,  3, -5,  2]),
#  array([-5,  3, -5,  3]),
#  array([-5,  3, -5,  4]),
#  array([-5,  3, -5,  5]),
#  array([-5,  3, -4, -5]),
#  array([-5,  3, -4, -4]),
#  array([-5,  3, -4, -3]),
#  array([-5,  3, -4, -2]),
#  array([-5,  3, -4, -1]),
#  array([-5,  3, -4,  0]),
#  array([-5,  3, -4,  1]),
#  array([-5,  3, -4,  2]),
#  array([-5,  3, -4,  3]),
#  array([-5,  3, -4,  4]),
#  array([-5,  3, -4,  5]),
#  array([-5,  3, -3, -5]),
#  array([-5,  3, -3, -4]),
#  array([-5,  3, -3, -3]),
#  array([-5,  3, -3, -2]),
#  array([-5,  3, -3, -1]),
#  array([-5,  3, -3,  0]),
#  array([-5,  3, -3,  1]),
#  array([-5,  3, -3,  2]),
#  array([-5,  3, -3,  3]),
#  array([-5,  3, -3,  4]),
#  ...]

# %%
np.allclose(sc_cands, sc_cands2)
# Out:
# True

# %%
hal2._gen_ham([0,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 hal2._gen_ham([0,0])
#
# NameError: name 'hal2' is not defined
