# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
filling_frac = [i/9 for i in range(8, 3, -1)]
omega_i = [1.977, 1.634, 1.365, 1.082, 0.839]
omega_til = [0.445, 0.137, 0.088, 0.021, 0.009]

# %%
plt.scatter(filling_frac, omega_i)
plt.scatter(filling_frac, omega_til)
